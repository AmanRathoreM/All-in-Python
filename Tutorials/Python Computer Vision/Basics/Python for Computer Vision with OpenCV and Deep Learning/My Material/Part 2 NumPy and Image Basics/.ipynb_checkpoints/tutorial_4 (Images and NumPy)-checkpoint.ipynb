# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 01-07-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>Images and NumPy</em></h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pic=Image.open("00-puppy.jpg")
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300 at 0x212007C2A30>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
pic_arr
# Out:
# array([[[95, 81, 78],
#         [97, 83, 80],
#         [98, 84, 81],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [96, 82, 79],
#         [96, 82, 79],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [94, 80, 77],
#         [94, 80, 77],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        ...,
#
#        [[19, 29, 20],
#         [20, 30, 21],
#         [20, 30, 21],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [20, 30, 21],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [19, 29, 20],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]]], dtype=uint8)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
# R G B
plt.title('Red')
plt.imshow(pic_arr[:,:,0])

# %%
plt.title('Green')
plt.imshow(pic_arr[:,:,1])

# %%
plt.title('Blue')
plt.imshow(pic_arr[:,:,2])

# %%
plt.imshow(pic_arr[:,:,:])

# %%
plt.subplot(2, 3, 1)
plt.title('Red')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,0])
plt.subplot(2, 3, 2)
plt.title('Green')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,1])
plt.subplot(2, 3, 3)
plt.title('Blue')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,2])
plt.subplot(2, 3, 4)
plt.title('Red-Green')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,0:1])
plt.subplot(2, 3, 5)
plt.title('Green-Blue')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,1:2])
plt.subplot(2, 3, 6)
plt.title('Real-Image')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,:])
plt.tight_layout(pad=.2)

# %%
plt.subplot(2, 3, 1)
plt.title('Red')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,0],cmap='gray')
plt.subplot(2, 3, 2)
plt.title('Green')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,1],cmap='gray')
plt.subplot(2, 3, 3)
plt.title('Blue')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,2],cmap='gray')
plt.subplot(2, 3, 4)
plt.title('Red-Green')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,0:1],cmap='gray')
plt.subplot(2, 3, 5)
plt.title('Green-Blue')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,1:2],cmap='gray')
plt.subplot(2, 3, 6)
plt.title('Real-Image')
plt.yticks(rotation=45)
plt.imshow(pic_arr[:,:,:],cmap='gray')
plt.tight_layout(pad=.2)

# %%
pic_red_removed=pic_arr.copy()
pic_red_removed[:,:,0]=0

# %%
plt.imshow(pic_red_removed)

# %%
pic_green_removed=pic_arr.copy()
pic_green_removed[:,:,1]=0

# %%
plt.imshow(pic_green_removed)

# %%
pic_blue_removed=pic_arr.copy()
pic_blue_removed[:,:,2]=0

# %%
plt.imshow(pic_blue_removed)

# %%
plt.subplot(1, 3, 1)
plt.title('Red-Removed')
plt.yticks(rotation=45)
plt.imshow(pic_red_removed)
plt.subplot(1, 3, 2)
plt.title('Green-Removed')
plt.yticks(rotation=45)
plt.imshow(pic_green_removed)
plt.subplot(1, 3, 3)
plt.title('Blue-Removed')
plt.yticks(rotation=45)
plt.imshow(pic_blue_removed)
plt.tight_layout(pad=.2)

# %%
pic_red=pic_arr.copy()
pic_red[:,:,1]=0
pic_red[:,:,2]=0
plt.title('Only-Red')
plt.imshow(pic_red)

# %%
pic_green=pic_arr.copy()
pic_green[:,:,0]=0
pic_green[:,:,2]=0
plt.title('Only-Green')
plt.imshow(pic_green)

# %%
pic_blue=pic_arr.copy()
pic_blue[:,:,0]=0
pic_blue[:,:,1]=0
plt.title('Only-Blue')
plt.imshow(pic_blue)

# %%
plt.subplot(2, 2, 1)
plt.title('Only-Red')
plt.yticks(rotation=45)
plt.imshow(pic_red)
plt.subplot(2, 2, 2)
plt.title('Only-Green')
plt.yticks(rotation=45)
plt.imshow(pic_green)
plt.subplot(2, 2, 3)
plt.title('Only-Blue')
plt.yticks(rotation=45)
plt.imshow(pic_blue)
plt.subplot(2, 2, 4)
plt.title('Real-Image')
plt.yticks(rotation=45)
plt.imshow(pic)
plt.tight_layout(pad=.5)
