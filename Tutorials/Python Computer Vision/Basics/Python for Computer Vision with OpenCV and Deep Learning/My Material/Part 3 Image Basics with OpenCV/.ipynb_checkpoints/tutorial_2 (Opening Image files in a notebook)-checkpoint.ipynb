# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 01-07-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>Opening Image files in a notebook</em></h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread('00-puppy.jpg')
img
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
wrong_path_image=cv2.imread('wrong/path/which/does/not/exists/on/my/computer.png')
type(wrong_path_image)
# Out:
# NoneType

# %%
plt.imshow(img)

# %% [markdown]
# # The above Output is a strange Output because -
# ## MatPlotLib read image in format of RED-GREEN-BLUE
# ## OpenCV read image in format of BLUE-GREEN-RED

# %%
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray=cv2.imread('00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
img_gray
# Out:
# array([[85, 87, 88, ..., 26, 26, 26],
#        [85, 86, 86, ..., 26, 26, 26],
#        [85, 84, 84, ..., 26, 26, 26],
#        ...,
#        [25, 26, 26, ..., 27, 28, 28],
#        [26, 26, 25, ..., 27, 28, 28],
#        [26, 25, 25, ..., 27, 28, 28]], dtype=uint8)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(img_gray,cmap='afmhot')

# %%
plt.imshow(img_gray,cmap='rainbow')

# %%
plt.imshow(cv2.resize(img,(2920,700)))

# %%
plt.imshow(cv2.flip(img,0))

# %%
plt.imshow(cv2.flip(img,1))

# %%
plt.imshow(cv2.flip(img,-1))

# %%
cv2.imwrite('Flipped image.png',cv2.flip(img,-1))
# Out:
# True

# %%
plt.figure(figsize=(16,9))
plt.imshow(img_gray,cmap='gist_stern')

# %%
plt.figure(figsize=(16,9))
plt.imshow(img_gray,cmap='gist_stern_r')
