# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 21-06-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>Label Based Indexing Part 2</em></h1>

# %%
import pandas as pd

# %%
summer_olmypic_data_csv=pd.read_csv('summer_data.csv',index_col='Athlete')
summer_olmypic_data_csv
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer_olmypic_data_csv.loc['ANDRIANOV, Nikolay','Medal']
# Out:
# Athlete
# ANDRIANOV, Nikolay      Gold
# ANDRIANOV, Nikolay    Silver
# ANDRIANOV, Nikolay    Bronze
# ANDRIANOV, Nikolay      Gold
# ANDRIANOV, Nikolay      Gold
# ANDRIANOV, Nikolay    Silver
# ANDRIANOV, Nikolay    Bronze
# ANDRIANOV, Nikolay      Gold
# ANDRIANOV, Nikolay    Silver
# ANDRIANOV, Nikolay      Gold
# ANDRIANOV, Nikolay    Silver
# ANDRIANOV, Nikolay    Bronze
# ANDRIANOV, Nikolay    Silver
# ANDRIANOV, Nikolay      Gold
# ANDRIANOV, Nikolay      Gold
# Name: Medal, dtype: object

# %%
summer_olmypic_data_csv.loc[['PHELPS, Michael','ANDRIANOV, Nikolay'],['Medal','Event','Year']]
# Out:
#                      Medal                   Event  Year
# Athlete
# PHELPS, Michael       Gold          100M Butterfly  2004
# PHELPS, Michael       Gold          200M Butterfly  2004
# PHELPS, Michael     Bronze          200M Freestyle  2004
# PHELPS, Michael       Gold  200M Individual Medley  2004
# PHELPS, Michael       Gold  400M Individual Medley  2004
# PHELPS, Michael     Bronze  4X100M Freestyle Relay  2004
# PHELPS, Michael       Gold     4X100M Medley Relay  2004
# PHELPS, Michael       Gold  4X200M Freestyle Relay  2004
# PHELPS, Michael       Gold          100M Butterfly  2008
# PHELPS, Michael       Gold          200M Butterfly  2008
# PHELPS, Michael       Gold          200M Freestyle  2008
# PHELPS, Michael       Gold  200M Individual Medley  2008
# PHELPS, Michael       Gold  400M Individual Medley  2008
# PHELPS, Michael       Gold  4X100M Freestyle Relay  2008
# PHELPS, Michael       Gold     4X100M Medley Relay  2008
# ...

# %%
summer_olmypic_data_csv.loc[:'CHASAPIS, Spiridon']
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer_olmypic_data_csv.loc['DRIVAS, Dimitrios':'CHASAPIS, Spiridon']
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer_olmypic_data_csv.loc['DRIVAS, Dimitrios':'CHASAPIS, Spiridon',['Medal','Event','Year']]
# Out:
#                      Medal                       Event  Year
# Athlete
# DRIVAS, Dimitrios   Bronze  100M Freestyle For Sailors  1896
# MALOKINIS, Ioannis    Gold  100M Freestyle For Sailors  1896
# CHASAPIS, Spiridon  Silver  100M Freestyle For Sailors  1896
