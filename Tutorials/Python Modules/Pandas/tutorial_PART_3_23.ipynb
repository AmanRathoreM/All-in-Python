# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 22-06-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>Advance Indexing and Slicing</em></h1>

# %%
import pandas as pd

# %%
summer_olmypic_data_csv=pd.read_csv('summer_data.csv')
summer_olmypic_data_csv
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
rows=list(range(5,9))+list(range(20012,20019))+[5698,31021]
rows
# Out:
# [5, 6, 7, 8, 20012, 20013, 20014, 20015, 20016, 20017, 20018, 5698, 31021]

# %%
summer_olmypic_data_csv.iloc[rows]
# Out:
#        Year       City       Sport       Discipline                Athlete  \
# 5      1896     Athens    Aquatics         Swimming  CHOROPHAS, Efstathios
# 6      1896     Athens    Aquatics         Swimming          HAJOS, Alfred
# 7      1896     Athens    Aquatics         Swimming       ANDREOU, Joannis
# 8      1896     Athens    Aquatics         Swimming  CHOROPHAS, Efstathios
# 20012  1992  Barcelona   Athletics        Athletics  MOLLER, Lorraine Mary
# 20013  1992  Barcelona   Athletics        Athletics    YEGOROVA, Valentina
# 20014  1992  Barcelona   Athletics        Athletics          ARIMORI, Yuko
# 20015  1992  Barcelona   Athletics        Athletics   GARCIA CHICO, Javier
# 20016  1992  Barcelona   Athletics        Athletics        TARASOV, Maksim
# 20017  1992  Barcelona   Athletics        Athletics       TRANDENKOV, Igor
# 20018  1992  Barcelona   Athletics        Athletics     LYKHO, Viatcheslav
# ...

# %%
summer_olmypic_data_csv#.columns[:3].to_list()+["Gender","Event"]
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer_olmypic_data_csv.columns[:3]#.to_list()+["Gender","Event"]
# Out:
# Index(['Year', 'City', 'Sport'], dtype='object')

# %%
summer_olmypic_data_csv.columns[:3].to_list()#+["Gender","Event"]
# Out:
# ['Year', 'City', 'Sport']

# %%
col=summer_olmypic_data_csv.columns[:3].to_list()+["Gender","Event"]
col
# Out:
# ['Year', 'City', 'Sport', 'Gender', 'Event']

# %%
summer_olmypic_data_csv.loc[:,col]
# Out:
#        Year    City      Sport Gender                       Event
# 0      1896  Athens   Aquatics    Men              100M Freestyle
# 1      1896  Athens   Aquatics    Men              100M Freestyle
# 2      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 3      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 4      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# ...     ...     ...        ...    ...                         ...
# 31160  2012  London  Wrestling    Men                    Wg 84 KG
# 31161  2012  London  Wrestling    Men                    Wg 96 KG
# 31162  2012  London  Wrestling    Men                    Wg 96 KG
# 31163  2012  London  Wrestling    Men                    Wg 96 KG
# 31164  2012  London  Wrestling    Men                    Wg 96 KG
#
# [31165 rows x 5 columns]

# %%
summer_olmypic_data_csv.loc[:,col+['Athlete']]
# Out:
#        Year    City      Sport Gender                       Event  \
# 0      1896  Athens   Aquatics    Men              100M Freestyle
# 1      1896  Athens   Aquatics    Men              100M Freestyle
# 2      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 3      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 4      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# ...     ...     ...        ...    ...                         ...
# 31160  2012  London  Wrestling    Men                    Wg 84 KG
# 31161  2012  London  Wrestling    Men                    Wg 96 KG
# 31162  2012  London  Wrestling    Men                    Wg 96 KG
# 31163  2012  London  Wrestling    Men                    Wg 96 KG
# 31164  2012  London  Wrestling    Men                    Wg 96 KG
#
#                          Athlete
# 0                  HAJOS, Alfred
# 1               HERSCHMANN, Otto
# 2              DRIVAS, Dimitrios
# 3             MALOKINIS, Ioannis
# ...

# %%
summer_olmypic_data_csv.loc[[200,300],['Athlete','Event']]
# Out:
#                       Athlete        Event
# 200               KEMP, Peter   Water Polo
# 300  SHELDON, Lewis Pendleton  Triple Jump
