# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 25-06-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>More in Seaborn Histograms</em></h1>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('dataset_tips.csv',usecols=['total_bill','tip','size'])
data
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
total_bill=data.total_bill.sort_values()
total_bill
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins=np.linspace(1,55,12,dtype=int)
bins
# Out:
# array([ 1,  5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55])

# %%
sns.distplot(total_bill)
# Out:
# C:\Users\amanr\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(total_bill,bins=bins)
# Out:
# C:\Users\amanr\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(total_bill,color='deepskyblue',aspect =2.5,bins=bins,kde=True)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sns.displot(total_bill,color='deepskyblue',aspect =2.5,bins=bins,kde=True)
plt.xticks(bins)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
customization=dict(color='deepskyblue',edgecolor='r',lw=20,ls='--',alpha=.91)
sns.displot(total_bill,aspect =2.5,bins=bins,kde=True,**customization)
plt.xticks(bins)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sns.displot(total_bill,aspect =2.5,bins=bins,kde=True,rug=True,rug_kws=dict(color='k'))
plt.xticks(bins)
plt.legend()
# Out:
# No handles with labels found to put in legend.
