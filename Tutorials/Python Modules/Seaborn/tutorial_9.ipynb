# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 25-06-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>Seaborn HeatMap</em></h1>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
arr1_2d=np.linspace(1,10,12).reshape(3,4)
arr1_2d
# Out:
# array([[ 1.        ,  1.81818182,  2.63636364,  3.45454545],
#        [ 4.27272727,  5.09090909,  5.90909091,  6.72727273],
#        [ 7.54545455,  8.36363636,  9.18181818, 10.        ]])

# %%
plt.figure(figsize=(16,9))
sns.heatmap(arr1_2d)
# Out:
# <AxesSubplot:>

# %%
dataset_global_warming=pd.read_csv("dataset_who_is_responsible_for_global_warming.csv")
dataset_global_warming
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0           Aruba          ABW  CO2 emissions (metric tons per capita)
# 1     Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2          Angola          AGO  CO2 emissions (metric tons per capita)
# 3         Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Arab World          ARB  CO2 emissions (metric tons per capita)
# ..            ...          ...                                     ...
# 236         Samoa          WSM  CO2 emissions (metric tons per capita)
# 237         Yemen          YEM  CO2 emissions (metric tons per capita)
# 238  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 239        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 240      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#      Indicator Code       2000       2001       2002       2003       2004  \
# 0    EN.ATM.CO2E.PC  26.194875  25.934024  25.671162  26.420452  26.517293
# 1    EN.ATM.CO2E.PC   0.038506   0.039002   0.048716   0.051830   0.039378
# 2    EN.ATM.CO2E.PC   0.580353   0.573047   0.720769   0.497975   0.996165
# 3    EN.ATM.CO2E.PC   0.978175   1.053304   1.229541   1.412697   1.376213
# 4    EN.ATM.CO2E.PC   3.684441   3.590303   3.588036   3.779889   4.051465
# ..              ...        ...        ...        ...        ...        ...
# 236  EN.ATM.CO2E.PC   0.819042   0.835469   0.830662   0.866893   0.840956
# 237  EN.ATM.CO2E.PC   0.819164   0.881350   0.833251   0.889143   0.943264
# 238  EN.ATM.CO2E.PC   8.280765   8.020756   7.583814   8.488351   9.330796
# 239  EN.ATM.CO2E.PC   0.173057   0.176166   0.178397   0.184923   0.182854
# 240  EN.ATM.CO2E.PC   1.139201   1.018598   0.957193   0.843469   0.742440
#
#           2005       2006       2007       2008       2009       2010  \
# 0    27.200708  26.948260  27.895574  26.230847  25.915833  24.670529
# 1     0.052948   0.063728   0.085418   0.154101   0.241723   0.293837
# 2     0.979740   1.098884   1.197844   1.181527   1.232495   1.243406
# 3     1.412498   1.302576   1.322335   1.484311   1.495600   1.578574
# 4     4.168486   4.268240   4.100226   4.390401   4.542151   4.615758
# ..         ...        ...        ...        ...        ...        ...
# 236   0.896731   0.911212   0.945487   0.979060   1.011854   1.004361
# 237   0.973808   1.007360   0.964139   0.999238   1.069059   0.992602
# 238   8.539756   9.073200   9.352665   9.854219   9.870597   9.190699
# 239   0.189859   0.185076   0.151567   0.165936   0.186396   0.194337
# 240   0.832299   0.796028   0.741658   0.573101   0.405716   0.552146
#
#           2011       2012      2013      2014
# 0    24.505835  13.155542  8.351294  8.408363
# 1     0.412017   0.350371  0.315602  0.299445
# 2     1.252789   1.330843  1.254617  1.291328
# 3     1.803715   1.692908  1.749211  1.978763
# 4     4.537755   4.813631  4.650474  4.860234
# ..         ...        ...       ...       ...
# 236   1.074708   1.046640  1.038064  1.029788
# 237   0.810900   0.749447  0.996885  0.864835
# 238   9.004033   8.845033  8.673963  8.980119
# 239   0.205911   0.249457  0.261113  0.288271
# 240   0.664751   0.529703  0.775564  0.779956
#
# [241 rows x 19 columns]

# %%
dataset_global_warming.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    241 non-null    object
#  1   Country Code    241 non-null    object
#  2   Indicator Name  241 non-null    object
#  3   Indicator Code  241 non-null    object
#  4   2000            241 non-null    float64
#  5   2001            241 non-null    float64
#  6   2002            241 non-null    float64
#  7   2003            241 non-null    float64
#  8   2004            241 non-null    float64
#  9   2005            241 non-null    float64
#  10  2006            241 non-null    float64
#  11  2007            241 non-null    float64
#  12  2008            241 non-null    float64
#  13  2009            241 non-null    float64
#  14  2010            241 non-null    float64
#  15  2011            241 non-null    float64
#  16  2012            241 non-null    float64
#  17  2013            241 non-null    float64
#  18  2014            241 non-null    float64
# dtypes: float64(15), object(4)
# memory usage: 35.9+ KB

# %%
dataset_global_warming=dataset_global_warming.drop(['Country Code','Indicator Name','Indicator Code'],axis=1).set_index('Country Name')
dataset_global_warming
# Out:
#                    2000       2001       2002       2003       2004  \
# Country Name
# Aruba         26.194875  25.934024  25.671162  26.420452  26.517293
# Afghanistan    0.038506   0.039002   0.048716   0.051830   0.039378
# Angola         0.580353   0.573047   0.720769   0.497975   0.996165
# Albania        0.978175   1.053304   1.229541   1.412697   1.376213
# Arab World     3.684441   3.590303   3.588036   3.779889   4.051465
# ...                 ...        ...        ...        ...        ...
# Samoa          0.819042   0.835469   0.830662   0.866893   0.840956
# Yemen          0.819164   0.881350   0.833251   0.889143   0.943264
# South Africa   8.280765   8.020756   7.583814   8.488351   9.330796
# Zambia         0.173057   0.176166   0.178397   0.184923   0.182854
# Zimbabwe       1.139201   1.018598   0.957193   0.843469   0.742440
#
#                    2005       2006       2007       2008       2009  \
# Country Name
# Aruba         27.200708  26.948260  27.895574  26.230847  25.915833
# Afghanistan    0.052948   0.063728   0.085418   0.154101   0.241723
# Angola         0.979740   1.098884   1.197844   1.181527   1.232495
# Albania        1.412498   1.302576   1.322335   1.484311   1.495600
# Arab World     4.168486   4.268240   4.100226   4.390401   4.542151
# ...                 ...        ...        ...        ...        ...
# Samoa          0.896731   0.911212   0.945487   0.979060   1.011854
# Yemen          0.973808   1.007360   0.964139   0.999238   1.069059
# South Africa   8.539756   9.073200   9.352665   9.854219   9.870597
# Zambia         0.189859   0.185076   0.151567   0.165936   0.186396
# Zimbabwe       0.832299   0.796028   0.741658   0.573101   0.405716
#
#                    2010       2011       2012      2013      2014
# Country Name
# Aruba         24.670529  24.505835  13.155542  8.351294  8.408363
# Afghanistan    0.293837   0.412017   0.350371  0.315602  0.299445
# Angola         1.243406   1.252789   1.330843  1.254617  1.291328
# Albania        1.578574   1.803715   1.692908  1.749211  1.978763
# Arab World     4.615758   4.537755   4.813631  4.650474  4.860234
# ...                 ...        ...        ...       ...       ...
# Samoa          1.004361   1.074708   1.046640  1.038064  1.029788
# Yemen          0.992602   0.810900   0.749447  0.996885  0.864835
# South Africa   9.190699   9.004033   8.845033  8.673963  8.980119
# Zambia         0.194337   0.205911   0.249457  0.261113  0.288271
# Zimbabwe       0.552146   0.664751   0.529703  0.775564  0.779956
#
# [241 rows x 15 columns]

# %%
dataset_global_warming.describe()
# Out:
#              2000        2001        2002        2003        2004        2005  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean     4.614925    4.668885    4.655261    4.790053    4.837024    4.886234
# std      6.405521    6.556147    6.351543    6.399624    6.323803    6.461455
# min      0.017293    0.017276    0.018616    0.019195    0.022610    0.020747
# 25%      0.748457    0.771026    0.788668    0.841729    0.859576    0.865613
# 50%      2.380762    2.591078    2.561299    2.826113    2.747360    2.897312
# 75%      6.603843    6.917751    6.968253    7.261476    7.199253    7.087902
# max     58.639359   67.106018   63.354472   60.299572   56.590834   58.918733
#
#              2006        2007        2008        2009        2010        2011  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean     4.957604    5.004323    5.007368    4.799826    4.921601    4.880092
# std      6.623232    6.468055    6.248977    5.923046    5.960613    5.884763
# min      0.024366    0.023555    0.023219    0.022462    0.024260    0.026762
# 25%      0.819492    0.891708    0.868950    0.841112    0.842662    0.840118
# 50%      2.941930    2.949279    3.029991    2.993133    2.948962    2.930914
# 75%      7.150837    6.941256    7.157192    6.447493    6.721960    6.762517
# max     62.823536   53.190986   46.672138   43.514477   40.742018   41.205645
#
#              2012        2013        2014
# count  241.000000  241.000000  241.000000
# mean     4.824479    4.758962    4.743817
# std      5.794820    5.562977    5.733063
# min      0.030297    0.030176    0.044485
# 25%      0.827960    0.856576    0.880445
# 50%      3.025851    3.005566    3.063307
# 75%      6.679992    6.736652    6.379149
# max     44.617929   37.780085   45.423240

# %%
plt.figure(figsize=(16,150))
sns.heatmap(dataset_global_warming)
# Out:
# <AxesSubplot:ylabel='Country Name'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(dataset_global_warming[:50])
# Out:
# <AxesSubplot:ylabel='Country Name'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(dataset_global_warming[:20],vmin=0,vmax=67.106018)
# Out:
# <AxesSubplot:ylabel='Country Name'>

# %%
rows_in_data_frame=20
max_value_in_data_frame=100 # use values of more than 11 (refrence arr06)
indeces=np.array(['arr01','arr02','arr03','arr04','arr05','arr06','arr07','arr08','arr09','arr10'])
arr01=np.linspace(12,max_value_in_data_frame-.9,rows_in_data_frame)
arr02=np.random.uniform(0,max_value_in_data_frame,rows_in_data_frame)
arr03=np.linspace(.99,max_value_in_data_frame-50.9,rows_in_data_frame)
arr04=np.random.uniform(0,max_value_in_data_frame,rows_in_data_frame)
arr05=np.random.uniform(0,max_value_in_data_frame,rows_in_data_frame)
arr06=np.linspace(.9,max_value_in_data_frame-10.99,rows_in_data_frame)
arr06=np.sort(arr06)[::-1]
arr07=np.linspace(.99,max_value_in_data_frame-.9,rows_in_data_frame)
arr08=np.random.uniform(0,max_value_in_data_frame,rows_in_data_frame)
arr09=np.random.uniform(0,max_value_in_data_frame,rows_in_data_frame)
arr10=np.linspace(.99,max_value_in_data_frame-.9,rows_in_data_frame)
arr10=np.sort(arr10)[::-1]
main_arr = np.vstack((arr01,arr02,arr03,arr04,arr05,arr06,arr07,arr08,arr09,arr10))
main_arr
data_2=pd.DataFrame(main_arr).set_index(indeces)
data_2
# Out:
#               0          1          2          3          4          5   \
# arr01  12.000000  16.584211  21.168421  25.752632  30.336842  34.921053
# arr02  48.672725   3.238614  14.626598  91.374401  86.225154  54.873558
# arr03   0.990000   3.522105   6.054211   8.586316  11.118421  13.650526
# arr04  64.335133  51.908525  10.684452  23.182387  56.970203  90.685123
# arr05  43.201341  75.278779  62.892684  23.787415  37.146985  40.043947
# arr06  89.010000  84.372632  79.735263  75.097895  70.460526  65.823158
# arr07   0.990000   6.153684  11.317368  16.481053  21.644737  26.808421
# arr08  20.813829  97.894599  56.827887  64.957140  54.330735  53.450142
# arr09  50.316664  64.341195  72.061517  26.514672  58.663143  86.297164
# arr10  99.100000  93.936316  88.772632  83.608947  78.445263  73.281579
#
#               6          7          8          9          10         11  \
# arr01  39.505263  44.089474  48.673684  53.257895  57.842105  62.426316
# arr02  60.650922  50.078071  95.450002  47.471389  39.426553  86.691377
# arr03  16.182632  18.714737  21.246842  23.778947  26.311053  28.843158
# arr04  62.775003  84.778257  63.298286  37.576463  18.635899  29.342260
# arr05  17.850741  19.086953  88.656592  69.973617  72.603562  43.184232
# arr06  61.185789  56.548421  51.911053  47.273684  42.636316  37.998947
# arr07  31.972105  37.135789  42.299474  47.463158  52.626842  57.790526
# arr08  55.939219  42.300164  79.513968   6.699892   3.808782  84.943827
# arr09  73.642904  53.652283  28.259734  69.504610  28.472465  18.418105
# arr10  68.117895  62.954211  57.790526  52.626842  47.463158  42.299474
#
#               12         13         14         15         16         17  \
# arr01  67.010526  71.594737  76.178947  80.763158  85.347368  89.931579
# arr02  30.616754  74.004454  14.767704  63.811288  71.602742  76.602104
# arr03  31.375263  33.907368  36.439474  38.971579  41.503684  44.035789
# arr04  33.176843  56.958484   0.789751   0.615759   8.271490   8.890147
# arr05  74.902370  44.508875  12.478508  93.796958  72.997385  42.985582
# arr06  33.361579  28.724211  24.086842  19.449474  14.812105  10.174737
# arr07  62.954211  68.117895  73.281579  78.445263  83.608947  88.772632
# arr08   9.267035   8.680112  50.036255   3.646668  77.215500  36.942807
# arr09  75.407721  85.685985  86.772516  58.058883  18.346247  69.008508
# arr10  37.135789  31.972105  26.808421  21.644737  16.481053  11.317368
#
#               18         19
# arr01  94.515789  99.100000
# arr02  28.121155  16.345242
# arr03  46.567895  49.100000
# arr04  40.838947  67.506085
# arr05  87.595650  63.363260
# arr06   5.537368   0.900000
# arr07  93.936316  99.100000
# arr08  63.509742  62.702001
# arr09  83.674575  15.560969
# arr10   6.153684   0.990000

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='nipy_spectral_r')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='nipy_spectral')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='rainbow_r')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='hot')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data_2,cmap='hot',annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
arr1 = np.arange(1,13).reshape(4,3) 
annot_arr = np.array([['a00','a01','a02'],
                      ['a10','a11','a12'],
                      ['a20','a21','a22'],
                      ['a30','a31','a32']])
 
sns.heatmap(arr1, annot = annot_arr, fmt="s")
# Out:
# <AxesSubplot:>
