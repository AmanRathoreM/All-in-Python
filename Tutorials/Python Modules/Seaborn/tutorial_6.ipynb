# %% [markdown]
# <h1 style="text-align:center; font-size:160%; font-family:verdana;color:#F44A79;"><em>Date 25-06-2021</em></h1>

# %% [markdown]
# <h1 style="text-align:center; font-size:360%; font-family:verdana;color:#4A3E76;"><em>Seaborn Bar Plot</em></h1>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('dataset_tips.csv',usecols=['day','total_bill','tip','size','sex'])
data
# Out:
#      total_bill   tip     sex   day  size
# 0         16.99  1.01  Female   Sun     2
# 1         10.34  1.66    Male   Sun     3
# 2         21.01  3.50    Male   Sun     3
# 3         23.68  3.31    Male   Sun     2
# 4         24.59  3.61  Female   Sun     4
# ..          ...   ...     ...   ...   ...
# 239       29.03  5.92    Male   Sat     3
# 240       27.18  2.00  Female   Sat     2
# 241       22.67  2.00    Male   Sat     2
# 242       17.82  1.75    Male   Sat     2
# 243       18.78  3.00  Female  Thur     2
#
# [244 rows x 5 columns]

# %%
sns.barplot(x=data.total_bill)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.barplot(x=data.tip)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.barplot(x=data.day, y=data.total_bill)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', hue='sex',data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', hue='sex',data=data,capsize=.12)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
order=['Sun','Thur','Fri','Sat']
sns.barplot(x='day', y='total_bill', hue='sex',data=data,capsize=.22,order=order)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
           )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.max)
plt.title('Bar Graph With Max Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Max Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=50)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=10)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=100)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(y='day', 
            x='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=100)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='total_bill', 
            y='size', 
            hue='sex',
            data=data,capsize=.22,
            estimator=np.min,
            ci=100,
            n_boot=100,
            orient='h')
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=100,
            palette='winter_r')
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=100,
            palette='winter_r',
            saturation=20)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=100,
            palette='winter_r',
            saturation=20,
            errcolor='#B00B69')
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')

# %%
sns.barplot(x='day', 
            y='total_bill', 
            hue='sex',
            data=data,capsize=.22,
            order=order,
            hue_order=['Female','Male'],
            estimator=np.min,
            ci=100,
            n_boot=100,
            palette='winter_r',
            saturation=20,
            errcolor='#B00B69',
            dodge=False)
plt.title('Bar Graph With Min Bill Values')
# Out:
# Text(0.5, 1.0, 'Bar Graph With Min Bill Values')
